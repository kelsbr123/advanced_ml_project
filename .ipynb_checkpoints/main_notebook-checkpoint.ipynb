# %%
from comet_ml import start, login
from comet_ml.integration.pytorch import log_model, watch

# %%
import kagglehub
import numpy as np
from torch import nn
import matplotlib.pyplot as plt 
import pandas as pd
import os
from pathlib import Path
import torchvision.io as io
from torch.utils.data import DataLoader, Dataset, random_split, Subset, RandomSampler
from torchvision import transforms, utils
import torch
import torch.nn.functional as F
from sklearn import svm, model_selection, metrics
from skimage import io as sk_io

# %%
device = (
    "cuda"
    if torch.cuda.is_available()
    else "mps"
    if torch.backends.mps.is_available()
    else "cpu"
)
print(f"Using {device} device")
# Out:
# Using cuda device

# %%
dir = "./data"

path = kagglehub.dataset_download("masoudnickparvar/brain-tumor-mri-dataset", output_dir=dir + "/brain-tumor-mri-dataset")
print("Path to dataset files:", path)

path = kagglehub.dataset_download("tawsifurrahman/covid19-radiography-database", output_dir=dir+"/covid19-radiography-database")
print("Path to dataset files:", path)
# Out:
# Path to dataset files: ./data/brain-tumor-mri-dataset
# Path to dataset files: ./data/covid19-radiography-database

# %%
class scans_dataset(Dataset):
    def __init__(self, *, dataset, library = "torch"):
        self.dataset = dataset
        self.df = self.build_dataframe(dataset)
        self.length = self.df.shape[0]
        self.library = library

    def __getitem__(self, index):
        item = self.df.iloc[index]
        scan = io.read_image(item['scan'])
        crop = transforms.Resize(size=(256,256))
        if self.dataset == "covid":
            scan = crop(scan)
            scan = scan[0:1, :, :]
        else:
            target = (3,256,256)
            scan = self.__pad__(scan, target)
        return scan, item['class']
    
    def __len__(self):
        return self.df.shape[0]
        
    def __pad__(self, tensor, target_shape):
    # Calculate padding for each dimension in reverse order
    # (starts from the last dimension)
        if self.library == "torch":
            paddings = []
            for cur, target in zip(reversed(tensor.shape), reversed(target_shape)):
                diff = target - cur
                paddings.extend([0, diff])  # [pad_left, pad_right]
        
            return F.pad(tensor, tuple(paddings))
            
    def build_dataframe(self, dataset="covid"):
        df = pd.DataFrame()
        if dataset == "tumors":
            self.channels = 3
            classes = {"glioma":1, "meningioma":2, "notumor": 3, "pituitary":4}
            path = "data/brain-tumor-mri-dataset"
            for t in ["Training", "Testing"]:
                for f in [d for d in os.listdir(path + "/" + t) if os.path.isdir(path + "/" + t + "/" + d)]:
                    files = [f'{path}/{t}/{f}/{d}' for d in os.listdir(path + f'/{t}/{f}')]
                    label = Path(f).name
                    df = pd.concat([df, pd.DataFrame({'testing': t=="Testing", 'label': label, 'class': classes[label], 'scan': files})], ignore_index=True)
        elif dataset == "covid":
            self.channels = 1
            classes = {"COVID": 1, "Lung_Opacity":2, "Normal":3, "Viral Pneumonia":4}
            path = "data/covid19-radiography-database/COVID-19_Radiography_Dataset"
            for f in [d for d in os.listdir(path) if os.path.isdir(path+ "/"+ d)]:
                images = [f'{path}/{f}/images/{d}' for d in os.listdir(path + f'/{f}/images')]
                masks = [f'{path}/{f}/masks/{d}' for d in os.listdir(path+f'/{f}/masks')]
                label = Path(f).name
                df = pd.concat([df, pd.DataFrame({'label': label, 'class': classes[label], 'scan': images, 'mask': masks})], ignore_index=True)
        else:
            raise ValueError("No such dataset")
        
        return df

# %%
class ResidualLayer(nn.Module):
    def __init__(self, in_channels, out_channels):
        super(ResidualLayer, self).__init__()

        self.down_scale_flag = in_channels != out_channels
        self.mish = nn.Mish()

        self.conv = nn.Conv2d(
            in_channels=in_channels,
            out_channels = out_channels,
            kernel_size=(3,3),
            padding='same'
        )
        self.bn1 = nn.BatchNorm2d(out_channels)
        self.conv_2 = nn.Conv2d(
            in_channels=out_channels,
            out_channels = out_channels,
            kernel_size=(3,3),
            padding='same'
        )
        self.bn2 = nn.BatchNorm2d(out_channels)

        self.down_scale = nn.Sequential(
            nn.Conv2d(
                in_channels=in_channels,
                out_channels=out_channels,
                kernel_size=(3,3),
                padding='same',
                
            ),
            nn.BatchNorm2d(out_channels)
        )

        
    def forward(self, x):
        identity = self.down_scale(x) if self.down_scale_flag else x
        x = self.conv(x)
        x = self.bn1(x)
        x = self.mish(x)
        x = self.conv_2(x)
        x = self.bn2(x)
        x = self.mish(x + identity)
        return x

# %%
class scan_cnn(nn.Module):
    def __init__(self, n_classes, input_channels, image_size: tuple, h_params):
        super(scan_cnn, self).__init__()
        self.layers = 4
        
        self.conv_block = nn.Conv2d(in_channels=input_channels,
                                    out_channels=16,
                                    kernel_size=(3,3),
                                    padding='same')
        self.mish = nn.Mish()
        self.norm = nn.BatchNorm2d(16)
        self.dropout = nn.Dropout(p = h_params['dropout'])
        self.residual_block_1 = nn.Sequential(
            ResidualLayer(16,16),
            ResidualLayer(16,16),
            ResidualLayer(16,16),
            nn.AvgPool2d((h_params['kernel_size'], h_params['kernel_size']), 
                         (h_params['stride'], h_params['stride']))
        )
        self.residual_block_2 = nn.Sequential(
            ResidualLayer(16, 32),
            ResidualLayer(32, 32),
            ResidualLayer(32, 32),
            nn.AvgPool2d((h_params['kernel_size'], h_params['kernel_size']), 
                         (h_params['stride'], h_params['stride']))
        )
        self.residual_block_3 = nn.Sequential(
            ResidualLayer(32, 64),
            ResidualLayer(64, 64),
            ResidualLayer(64, 64),
            nn.AvgPool2d((h_params['kernel_size'], h_params['kernel_size']), 
                         (h_params['stride'], h_params['stride']))
        )
        self.residual_block_4 = nn.Sequential(
            ResidualLayer(64, 128),
            ResidualLayer(128, 128),
            ResidualLayer(128, 128),
            nn.AvgPool2d((h_params['kernel_size'], h_params['kernel_size']), 
                         (h_params['stride'], h_params['stride']))
        )

        self.flatten = nn.Flatten(1)
        in_features = image_size[0] // h_params['kernel_size']**4 * image_size[1] // h_params['kernel_size']**4 * 128
        
        self.linear = nn.Linear(
            in_features = in_features,
            out_features = n_classes
        )
    
    def forward(self, x):
        x = self.conv_block(x)
        x = self.norm(x)
        x = self.mish(x)

        x = self.residual_block_1(x)
        x = self.residual_block_2(x)
        x = self.residual_block_3(x)
        x = self.residual_block_4(x)
        
        x = self.dropout(x)

        x = self.flatten(x)
        x = self.linear(x)

        return x

# %%
def train(dataset, image_model, h_params, experiment):
    sum_loss = 0
    losses = []
    i = 0
    optimizer = torch.optim.Adam(image_model.parameters(), lr=h_params['learning_rate'])
    loss_fn = torch.nn.NLLLoss()
    log_softmax = nn.LogSoftmax(dim=0)
    

    for epoch in range(h_params['epochs']):
        total = 0
        correct = 0
        experiment.log_current_epoch(epoch)
        for (X, y) in dataset:
            # X = crop(X)
            X = X.float()
            X, Y = X.to(device), y.to(device)
            optimizer.zero_grad()

            output = image_model(X)
            output = log_softmax(output)
            loss = loss_fn(output, Y.long())

            loss.backward()
            optimizer.step()
            sum_loss += loss.item()
            losses.append(loss.item())

            _, predicted = torch.max(output.data, 1)
            total += Y.size(0)
            correct += float((predicted == Y.data).sum())

            # Log accuracy to Comet.ml
            experiment.log_metric("accuracy", 100 * correct / total, step=i)
            experiment.log_metric("loss", loss, step=i)

            
            i += 1
            
    return losses

# %%
def train_svm(dataset):
    clf = svm.SVC()
    X, y = [], []
    for i in range(0, dataset.length, dataset.length//600):
        img, label = dataset.__getitem__(i)
        img = img.flatten().tolist()
        X.append(img)
        y.append(label.item(0))
    X_train, X_test, y_train, y_test = model_selection.train_test_split(X, y, train_size=.8)
    clf.fit(X_train, y_train)
    print(dataset.length)
    return clf, X_test, y_test

# %%
dataset = scans_dataset(dataset="covid", library="torch")
subset = Subset(dataset, range(0, dataset.length, dataset.length//1000))

# %%
login()

# %%
kernel_sizes = [2, 3, 4]
strides = [2, 3, 4]
epochs = [1000, 10000, 100000],
learning_rates = [.001, .01, .1]
batch_sizes = [20,25,40]
dropouts = [.05, .1, .2]
h_params = {'learning_rate': .005, 'epochs': 50, 'batch_size': 0, 'kernel_size': 0, 'stride': 1, 'dropout': 0}
for b in batch_sizes:
    for k in kernel_sizes:
        for d in dropouts:
            experiment = start(project="ml-project")
            h_params['batch_size'], h_params['kernel_size'], h_params['stride'], h_params['dropout'] = b, k, k, d                
            experiment.log_parameters(h_params)
            
            dataloader = DataLoader(subset, batch_size=b)
            
            image_model = scan_cnn(n_classes=4, input_channels=dataset.channels, image_size=(256,256), h_params=h_params).to(device)
            losses = train(dataloader, image_model, h_params, experiment)
            experiment.end()
# Out:
# COMET WARNING: As you are running in a Jupyter environment, you will need to call `experiment.end()` when finished to ensure all metrics and code are logged before exiting.
# COMET INFO: Experiment is live on comet.com https://www.comet.com/kelsbr123/ml-project/eeef20b12c044ea58c5740cc6191bfb5
#
# COMET WARNING: Unknown error exporting current conda environment
# COMET WARNING: Unknown error retrieving Conda package as an explicit file
# COMET WARNING: Unknown error retrieving Conda information
# COMET INFO: ---------------------------------------------------------------------------------------
# COMET INFO: Comet.ml Experiment Summary
# COMET INFO: ---------------------------------------------------------------------------------------
# COMET INFO:   Data:
# COMET INFO:     display_summary_level : 1
# COMET INFO:     name                  : tame_pear_6405
# COMET INFO:     url                   : https://www.comet.com/kelsbr123/ml-project/eeef20b12c044ea58c5740cc6191bfb5
# COMET INFO:   Metrics [count] (min, max):
# COMET INFO:     accuracy [1000]  : (5.0, 55.0)
# COMET INFO:     curr_epoch [100] : (0, 99)
# COMET INFO:     loss [1100]      : (3.016674041748047, 373.74493408203125)
# COMET INFO:   Parameters:
# COMET INFO:     batch_size    : 20
# COMET INFO:     dropout       : 0.05
# COMET INFO:     epochs        : 100
# COMET INFO:     kernel_size   : 2
# COMET INFO:     learning_rate : 0.01
# COMET INFO:     stride        : 2
# COMET INFO:   Uploads:
# COMET INFO:     environment details      : 1
# COMET INFO:     filename                 : 1
# COMET INFO:     git metadata             : 1
# COMET INFO:     git-patch (uncompressed) : 1 (6.04 KB)
# COMET INFO:     installed packages       : 1
# COMET INFO:     model graph              : 1
# COMET INFO:     notebook                 : 1
# COMET INFO:     os packages              : 1
# COMET INFO:     source_code              : 1
# COMET INFO:
# COMET WARNING: As you are running in a Jupyter environment, you will need to call `experiment.end()` when finished to ensure all metrics and code are logged before exiting.
# COMET INFO: Experiment is live on comet.com https://www.comet.com/kelsbr123/ml-project/a8b9f1f220414e31ae41247c5ff172c9
#
# COMET WARNING: Unknown error exporting current conda environment
# COMET WARNING: Unknown error retrieving Conda package as an explicit file
# COMET WARNING: Unknown error retrieving Conda information
# COMET INFO: ---------------------------------------------------------------------------------------
# COMET INFO: Comet.ml Experiment Summary
# COMET INFO: ---------------------------------------------------------------------------------------
# COMET INFO:   Data:
# COMET INFO:     display_summary_level : 1
# COMET INFO:     name                  : future_wood_4361
# COMET INFO:     url                   : https://www.comet.com/kelsbr123/ml-project/a8b9f1f220414e31ae41247c5ff172c9
# COMET INFO:   Metrics [count] (min, max):
# COMET INFO:     accuracy [1000]  : (5.0, 55.0)
# COMET INFO:     curr_epoch [100] : (0, 99)
# COMET INFO:     loss [1100]      : (3.0338730812072754, 112.95283508300781)
# COMET INFO:   Parameters:
# COMET INFO:     batch_size    : 20
# COMET INFO:     dropout       : 0.1
# COMET INFO:     epochs        : 100
# COMET INFO:     kernel_size   : 2
# COMET INFO:     learning_rate : 0.01
# COMET INFO:     stride        : 2
# COMET INFO:   Uploads:
# COMET INFO:     environment details      : 1
# COMET INFO:     filename                 : 1
# COMET INFO:     git metadata             : 1
# COMET INFO:     git-patch (uncompressed) : 1 (6.77 KB)
# COMET INFO:     installed packages       : 1
# COMET INFO:     model graph              : 1
# COMET INFO:     notebook                 : 1
# COMET INFO:     os packages              : 1
# COMET INFO:     source_code              : 1
# COMET INFO:
# COMET INFO: Please wait for metadata to finish uploading (timeout is 3600 seconds)
# COMET INFO: Uploading 3350 metrics, params and output messages
# COMET WARNING: As you are running in a Jupyter environment, you will need to call `experiment.end()` when finished to ensure all metrics and code are logged before exiting.
# COMET INFO: Experiment is live on comet.com https://www.comet.com/kelsbr123/ml-project/0db4ed7f97484d2d92fd9accba170dd5
#
# COMET WARNING: Unknown error exporting current conda environment
# COMET WARNING: Unknown error retrieving Conda package as an explicit file
# COMET WARNING: Unknown error retrieving Conda information
# COMET INFO: ---------------------------------------------------------------------------------------
# COMET INFO: Comet.ml Experiment Summary
# COMET INFO: ---------------------------------------------------------------------------------------
# COMET INFO:   Data:
# COMET INFO:     display_summary_level : 1
# COMET INFO:     name                  : geographical_pilaster_387
# COMET INFO:     url                   : https://www.comet.com/kelsbr123/ml-project/0db4ed7f97484d2d92fd9accba170dd5
# COMET INFO:   Metrics [count] (min, max):
# COMET INFO:     accuracy [1000]  : (5.0, 70.0)
# COMET INFO:     curr_epoch [100] : (0, 99)
# COMET INFO:     loss [1100]      : (2.996992588043213, 159.1005401611328)
# COMET INFO:   Parameters:
# COMET INFO:     batch_size    : 20
# COMET INFO:     dropout       : 0.2
# COMET INFO:     epochs        : 100
# COMET INFO:     kernel_size   : 2
# COMET INFO:     learning_rate : 0.01
# COMET INFO:     stride        : 2
# COMET INFO:   Uploads:
# COMET INFO:     environment details      : 1
# COMET INFO:     filename                 : 1
# COMET INFO:     git metadata             : 1
# COMET INFO:     git-patch (uncompressed) : 1 (6.77 KB)
# COMET INFO:     installed packages       : 1
# COMET INFO:     model graph              : 1
# COMET INFO:     notebook                 : 1
# COMET INFO:     os packages              : 1
# COMET INFO:     source_code              : 1
# COMET INFO:
# COMET INFO: Uploading 3347 metrics, params and output messages
# COMET WARNING: As you are running in a Jupyter environment, you will need to call `experiment.end()` when finished to ensure all metrics and code are logged before exiting.
# COMET INFO: Experiment is live on comet.com https://www.comet.com/kelsbr123/ml-project/fac0ef7305ac48b58ef107e4d8b8c95a
#
# COMET WARNING: Unknown error exporting current conda environment
# COMET WARNING: Unknown error retrieving Conda package as an explicit file
# COMET WARNING: Unknown error retrieving Conda information
# COMET INFO: ---------------------------------------------------------------------------------------
# COMET INFO: Comet.ml Experiment Summary
# COMET INFO: ---------------------------------------------------------------------------------------
# COMET INFO:   Data:
# COMET INFO:     display_summary_level : 1
# COMET INFO:     name                  : modern_cougar_7183
# COMET INFO:     url                   : https://www.comet.com/kelsbr123/ml-project/fac0ef7305ac48b58ef107e4d8b8c95a
# COMET INFO:   Metrics [count] (min, max):
# COMET INFO:     accuracy [1000]  : (0.0, 38.0)
# COMET INFO:     curr_epoch [100] : (0, 99)
# COMET INFO:     loss [1100]      : (2.995734930038452, 6.392989635467529)
# COMET INFO:   Parameters:
# COMET INFO:     batch_size    : 20
# COMET INFO:     dropout       : 0.05
# COMET INFO:     epochs        : 100
# COMET INFO:     kernel_size   : 4
# COMET INFO:     learning_rate : 0.01
# COMET INFO:     stride        : 4
# COMET INFO:   Uploads:
# COMET INFO:     environment details      : 1
# COMET INFO:     filename                 : 1
# COMET INFO:     git metadata             : 1
# COMET INFO:     git-patch (uncompressed) : 1 (6.77 KB)
# COMET INFO:     installed packages       : 1
# COMET INFO:     model graph              : 1
# COMET INFO:     notebook                 : 1
# COMET INFO:     os packages              : 1
# COMET INFO:     source_code              : 1
# COMET INFO:
# COMET WARNING: As you are running in a Jupyter environment, you will need to call `experiment.end()` when finished to ensure all metrics and code are logged before exiting.
# COMET INFO: Experiment is live on comet.com https://www.comet.com/kelsbr123/ml-project/43ce66bd11d5415ba659c1a33becc740
#
# COMET WARNING: Unknown error exporting current conda environment
# COMET WARNING: Unknown error retrieving Conda package as an explicit file
# COMET WARNING: Unknown error retrieving Conda information
# COMET INFO: ---------------------------------------------------------------------------------------
# COMET INFO: Comet.ml Experiment Summary
# COMET INFO: ---------------------------------------------------------------------------------------
# COMET INFO:   Data:
# COMET INFO:     display_summary_level : 1
# COMET INFO:     name                  : regular_pomelo_4172
# COMET INFO:     url                   : https://www.comet.com/kelsbr123/ml-project/43ce66bd11d5415ba659c1a33becc740
# COMET INFO:   Metrics [count] (min, max):
# COMET INFO:     accuracy [1000]  : (0.0, 50.0)
# COMET INFO:     curr_epoch [100] : (0, 99)
# COMET INFO:     loss [1100]      : (2.995767116546631, 39.09016799926758)
# COMET INFO:   Parameters:
# COMET INFO:     batch_size    : 20
# COMET INFO:     dropout       : 0.1
# COMET INFO:     epochs        : 100
# COMET INFO:     kernel_size   : 4
# COMET INFO:     learning_rate : 0.01
# COMET INFO:     stride        : 4
# COMET INFO:   Uploads:
# COMET INFO:     environment details      : 1
# COMET INFO:     filename                 : 1
# COMET INFO:     git metadata             : 1
# COMET INFO:     git-patch (uncompressed) : 1 (6.77 KB)
# COMET INFO:     installed packages       : 1
# COMET INFO:     model graph              : 1
# COMET INFO:     notebook                 : 1
# COMET INFO:     os packages              : 1
# COMET INFO:     source_code              : 1
# COMET INFO:
# COMET WARNING: As you are running in a Jupyter environment, you will need to call `experiment.end()` when finished to ensure all metrics and code are logged before exiting.
# COMET INFO: Experiment is live on comet.com https://www.comet.com/kelsbr123/ml-project/721466bb4eb844bd8e5be7d1682a1c3e
#
# COMET WARNING: Unknown error exporting current conda environment
# COMET WARNING: Unknown error retrieving Conda package as an explicit file
# COMET WARNING: Unknown error retrieving Conda information
# COMET INFO: ---------------------------------------------------------------------------------------
# COMET INFO: Comet.ml Experiment Summary
# COMET INFO: ---------------------------------------------------------------------------------------
# COMET INFO:   Data:
# COMET INFO:     display_summary_level : 1
# COMET INFO:     name                  : previous_arcade_1253
# COMET INFO:     url                   : https://www.comet.com/kelsbr123/ml-project/721466bb4eb844bd8e5be7d1682a1c3e
# COMET INFO:   Metrics [count] (min, max):
# COMET INFO:     accuracy [1000]  : (5.0, 55.0)
# COMET INFO:     curr_epoch [100] : (0, 99)
# COMET INFO:     loss [1100]      : (2.995732069015503, 5.647874355316162)
# COMET INFO:   Parameters:
# COMET INFO:     batch_size    : 20
# COMET INFO:     dropout       : 0.2
# COMET INFO:     epochs        : 100
# COMET INFO:     kernel_size   : 4
# COMET INFO:     learning_rate : 0.01
# COMET INFO:     stride        : 4
# COMET INFO:   Uploads:
# COMET INFO:     environment details      : 1
# COMET INFO:     filename                 : 1
# COMET INFO:     git metadata             : 1
# COMET INFO:     git-patch (uncompressed) : 1 (6.77 KB)
# COMET INFO:     installed packages       : 1
# COMET INFO:     model graph              : 1
# COMET INFO:     notebook                 : 1
# COMET INFO:     os packages              : 1
# COMET INFO:     source_code              : 1
# COMET INFO:
# COMET WARNING: As you are running in a Jupyter environment, you will need to call `experiment.end()` when finished to ensure all metrics and code are logged before exiting.
# COMET INFO: Experiment is live on comet.com https://www.comet.com/kelsbr123/ml-project/5a5fa1d1449f44158069c830dcde4f81
#
# COMET WARNING: Unknown error exporting current conda environment
# COMET WARNING: Unknown error retrieving Conda package as an explicit file
# COMET WARNING: Unknown error retrieving Conda information
# /venv/main/lib/python3.12/site-packages/torch/nn/modules/linear.py:124: UserWarning: Initializing zero-element tensors is a no-op
#   init.kaiming_uniform_(self.weight, a=math.sqrt(5))
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[13], line 18
#      14
#      15             dataloader = DataLoader(subset, batch_size=b)
#      16
#      17             image_model = scan_cnn(n_classes=4, input_channels=dataset.channels, image_size=(256,256), h_params=h_params).to(device)
# ---> 18             losses = train(dataloader, image_model, h_params, experiment)
#      19             experiment.end()
#
# Cell In[8], line 20, in train(dataset, image_model, h_params, experiment)
#      16             X = X.float()
#      17             X, Y = X.to(device), y.to(device)
#      18             optimizer.zero_grad()
#      19
# ---> 20             output = image_model(X)
#      21             output = log_softmax(output)
#      22             loss = loss_fn(output, Y.long())
#      23
#
# File /venv/main/lib/python3.12/site-packages/torch/nn/modules/module.py:1779, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1777     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1778 else:
# -> 1779     return self._call_impl(*args, **kwargs)
#
# File /venv/main/lib/python3.12/site-packages/torch/nn/modules/module.py:1790, in Module._call_impl(self, *args, **kwargs)
#    1785 # If we don't have any hooks, we want to skip the rest of the logic in
#    1786 # this function, and just call forward.
#    1787 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1788         or _global_backward_pre_hooks or _global_backward_hooks
#    1789         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1790     return forward_call(*args, **kwargs)
#    1792 result = None
#    1793 called_always_called_hooks = set()
#
# Cell In[7], line 57, in scan_cnn.forward(self, x)
#      53         x = self.mish(x)
#      54
#      55         x = self.residual_block_1(x)
#      56         x = self.residual_block_2(x)
# ---> 57         x = self.residual_block_3(x)
#      58         x = self.residual_block_4(x)
#      59
#      60         x = self.dropout(x)
#
# File /venv/main/lib/python3.12/site-packages/torch/nn/modules/module.py:1779, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1777     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1778 else:
# -> 1779     return self._call_impl(*args, **kwargs)
#
# File /venv/main/lib/python3.12/site-packages/torch/nn/modules/module.py:1790, in Module._call_impl(self, *args, **kwargs)
#    1785 # If we don't have any hooks, we want to skip the rest of the logic in
#    1786 # this function, and just call forward.
#    1787 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1788         or _global_backward_pre_hooks or _global_backward_hooks
#    1789         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1790     return forward_call(*args, **kwargs)
#    1792 result = None
#    1793 called_always_called_hooks = set()
#
# File /venv/main/lib/python3.12/site-packages/torch/nn/modules/container.py:253, in Sequential.forward(self, input)
#     249 """
#     250 Runs the forward pass.
#     251 """
#     252 for module in self:
# --> 253     input = module(input)
#     254 return input
#
# File /venv/main/lib/python3.12/site-packages/torch/nn/modules/module.py:1779, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1777     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1778 else:
# -> 1779     return self._call_impl(*args, **kwargs)
#
# File /venv/main/lib/python3.12/site-packages/torch/nn/modules/module.py:1790, in Module._call_impl(self, *args, **kwargs)
#    1785 # If we don't have any hooks, we want to skip the rest of the logic in
#    1786 # this function, and just call forward.
#    1787 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1788         or _global_backward_pre_hooks or _global_backward_hooks
#    1789         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1790     return forward_call(*args, **kwargs)
#    1792 result = None
#    1793 called_always_called_hooks = set()
#
# File /venv/main/lib/python3.12/site-packages/torch/nn/modules/pooling.py:779, in AvgPool2d.forward(self, input)
#     777 def forward(self, input: Tensor) -> Tensor:
#     778     """Runs the forward pass."""
# --> 779     return F.avg_pool2d(
#     780         input,
#     781         self.kernel_size,
#     782         self.stride,
#     783         self.padding,
#     784         self.ceil_mode,
#     785         self.count_include_pad,
#     786         self.divisor_override,
#     787     )
#
# RuntimeError: Given input size: (64x4x4). Calculated output size: (64x0x0). Output size is too small

# %%
clf, X_test, y_test = train_svm(dataset)

# %%
print(metrics.classification_report(y_test, clf.predict(X_test)))

# %%
avg_loss = []
for i in range(0,len(losses), 7):
    avg_loss.append(np.average(losses[i:i+7]))

plt.semilogy(list(range(0,len(avg_loss))), avg_loss)
plt.title("Average loss versus epoch")
plt.xlabel("Epoch")
plt.ylabel("Log Loss")
