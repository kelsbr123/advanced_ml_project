# %%
from comet_ml import start, login
from comet_ml.integration.pytorch import log_model, watch

# %%
import kagglehub
import numpy as np
from torch import nn
import matplotlib.pyplot as plt 
import pandas as pd
import os
from pathlib import Path
import torchvision.io as io
from torch.utils.data import DataLoader, Dataset, random_split, Subset, RandomSampler
from torchvision import transforms, utils
import torch
import torch.nn.functional as F
from sklearn import svm, model_selection, metrics
from skimage import io as sk_io

# %%
device = (
    "cuda"
    if torch.cuda.is_available()
    else "mps"
    if torch.backends.mps.is_available()
    else "cpu"
)
print(f"Using {device} device")
# Out:
# Using cuda device

# %%
dir = "./data"

path = kagglehub.dataset_download("masoudnickparvar/brain-tumor-mri-dataset", output_dir=dir + "/brain-tumor-mri-dataset")
print("Path to dataset files:", path)

path = kagglehub.dataset_download("tawsifurrahman/covid19-radiography-database", output_dir=dir+"/covid19-radiography-database")
print("Path to dataset files:", path)
# Out:
# Downloading to ./data/brain-tumor-mri-dataset/2.archive...
# 100%|██████████| 157M/157M [00:11<00:00, 14.5MB/s]
# Extracting files...
# Path to dataset files: ./data/brain-tumor-mri-dataset
# Downloading to ./data/covid19-radiography-database/5.archive...
# 100%|██████████| 778M/778M [00:58<00:00, 13.8MB/s]
# Extracting files...
# Path to dataset files: ./data/covid19-radiography-database

# %%
class scans_dataset(Dataset):
    def __init__(self, *, dataset, library = "torch"):
        self.dataset = dataset
        self.df = self.build_dataframe(dataset)
        self.length = self.df.shape[0]
        self.library = library

    def __getitem__(self, index):
        item = self.df.iloc[index]
        scan = io.read_image(item['scan'])
        crop = transforms.Resize(size=(256,256))
        if self.dataset == "covid":
            scan = crop(scan)
            scan = scan[0:1, :, :]
        else:
            target = (3,256,256)
            scan = self.__pad__(scan, target)
        return scan, item['class']
    
    def __len__(self):
        return self.df.shape[0]
        
    def __pad__(self, tensor, target_shape):
    # Calculate padding for each dimension in reverse order
    # (starts from the last dimension)
        if self.library == "torch":
            paddings = []
            for cur, target in zip(reversed(tensor.shape), reversed(target_shape)):
                diff = target - cur
                paddings.extend([0, diff])  # [pad_left, pad_right]
        
            return F.pad(tensor, tuple(paddings))
            
    def build_dataframe(self, dataset="covid"):
        df = pd.DataFrame()
        if dataset == "tumors":
            self.channels = 3
            classes = {"glioma":1, "meningioma":2, "notumor": 3, "pituitary":4}
            path = "data/brain-tumor-mri-dataset"
            for t in ["Training", "Testing"]:
                for f in [d for d in os.listdir(path + "/" + t) if os.path.isdir(path + "/" + t + "/" + d)]:
                    files = [f'{path}/{t}/{f}/{d}' for d in os.listdir(path + f'/{t}/{f}')]
                    label = Path(f).name
                    df = pd.concat([df, pd.DataFrame({'testing': t=="Testing", 'label': label, 'class': classes[label], 'scan': files})], ignore_index=True)
        elif dataset == "covid":
            self.channels = 1
            classes = {"COVID": 1, "Lung_Opacity":2, "Normal":3, "Viral Pneumonia":4}
            path = "data/covid19-radiography-database/COVID-19_Radiography_Dataset"
            for f in [d for d in os.listdir(path) if os.path.isdir(path+ "/"+ d)]:
                images = [f'{path}/{f}/images/{d}' for d in os.listdir(path + f'/{f}/images')]
                masks = [f'{path}/{f}/masks/{d}' for d in os.listdir(path+f'/{f}/masks')]
                label = Path(f).name
                df = pd.concat([df, pd.DataFrame({'label': label, 'class': classes[label], 'scan': images, 'mask': masks})], ignore_index=True)
        else:
            raise ValueError("No such dataset")
        
        return df

# %%
class ResidualLayer(nn.Module):
    def __init__(self, in_channels, out_channels):
        super(ResidualLayer, self).__init__()

        self.down_scale_flag = in_channels != out_channels
        self.mish = nn.Mish()

        self.conv = nn.Conv2d(
            in_channels=in_channels,
            out_channels = out_channels,
            kernel_size=(3,3),
            padding='same'
        )
        self.bn1 = nn.BatchNorm2d(out_channels)
        self.conv_2 = nn.Conv2d(
            in_channels=out_channels,
            out_channels = out_channels,
            kernel_size=(3,3),
            padding='same'
        )
        self.bn2 = nn.BatchNorm2d(out_channels)

        self.down_scale = nn.Sequential(
            nn.Conv2d(
                in_channels=in_channels,
                out_channels=out_channels,
                kernel_size=(3,3),
                padding='same',
                
            ),
            nn.BatchNorm2d(out_channels)
        )

        
    def forward(self, x):
        identity = self.down_scale(x) if self.down_scale_flag else x
        x = self.conv(x)
        x = self.bn1(x)
        x = self.mish(x)
        x = self.conv_2(x)
        x = self.bn2(x)
        x = self.mish(x + identity)
        return x

# %%
class scan_cnn(nn.Module):
    def __init__(self, n_classes, input_channels, image_size: tuple, h_params):
        super(scan_cnn, self).__init__()
        self.layers = 4
        
        self.conv_block = nn.Conv2d(in_channels=input_channels,
                                    out_channels=16,
                                    kernel_size=(3,3),
                                    padding='same')
        self.mish = nn.Mish()
        self.norm = nn.BatchNorm2d(16)
        self.dropout = nn.Dropout(p = h_params['dropout'])
        self.residual_block_1 = nn.Sequential(
            ResidualLayer(16,16),
            ResidualLayer(16,16),
            ResidualLayer(16,16),
            nn.AvgPool2d((h_params['kernel_size'], h_params['kernel_size']), 
                         (h_params['stride'], h_params['stride']))
        )
        self.residual_block_2 = nn.Sequential(
            ResidualLayer(16, 32),
            ResidualLayer(32, 32),
            ResidualLayer(32, 32),
            nn.AvgPool2d((h_params['kernel_size'], h_params['kernel_size']), 
                         (h_params['stride'], h_params['stride']))
        )
        self.residual_block_3 = nn.Sequential(
            ResidualLayer(32, 64),
            ResidualLayer(64, 64),
            ResidualLayer(64, 64),
            nn.AvgPool2d((h_params['kernel_size'], h_params['kernel_size']), 
                         (h_params['stride'], h_params['stride']))
        )
        self.residual_block_4 = nn.Sequential(
            ResidualLayer(64, 128),
            ResidualLayer(128, 128),
            ResidualLayer(128, 128),
            nn.AvgPool2d((h_params['kernel_size'], h_params['kernel_size']), 
                         (h_params['stride'], h_params['stride']))
        )

        self.flatten = nn.Flatten(1)
        in_features = image_size[0] // h_params['kernel_size']**4 * image_size[1] // h_params['kernel_size']**4 * 128
        
        self.linear = nn.Linear(
            in_features = in_features,
            out_features = n_classes
        )
    
    def forward(self, x):
        x = self.conv_block(x)
        x = self.norm(x)
        x = self.mish(x)

        x = self.residual_block_1(x)
        x = self.residual_block_2(x)
        x = self.residual_block_3(x)
        x = self.residual_block_4(x)
        
        x = self.dropout(x)

        x = self.flatten(x)
        x = self.linear(x)

        return x

# %%
def train(dataset, image_model, h_params, experiment):
    sum_loss = 0
    losses = []
    i = 0
    optimizer = torch.optim.Adam(image_model.parameters(), lr=h_params['learning_rate'])
    loss_fn = torch.nn.NLLLoss()
    log_softmax = nn.LogSoftmax(dim=0)
    

    for epoch in range(h_params['epochs']):
        total = 0
        correct = 0
        experiment.log_current_epoch(epoch)
        for (X, y) in dataset:
            # X = crop(X)
            X = X.float()
            X, Y = X.to(device), y.to(device)
            optimizer.zero_grad()

            output = image_model(X)
            output = log_softmax(output)
            loss = loss_fn(output, Y.long())

            loss.backward()
            optimizer.step()
            sum_loss += loss.item()
            losses.append(loss.item())

            _, predicted = torch.max(output.data, 1)
            total += Y.size(0)
            correct += float((predicted == Y.data).sum())

            # Log accuracy to Comet.ml
            experiment.log_metric("accuracy", 100 * correct / total, step=i)
            experiment.log_metric("loss", loss, step=i)

            
            i += 1
            
    return losses

# %%
def train_svm(dataset):
    clf = svm.SVC()
    X, y = [], []
    for i in range(0, dataset.length, dataset.length//600):
        img, label = dataset.__getitem__(i)
        img = img.flatten().tolist()
        X.append(img)
        y.append(label.item(0))
    X_train, X_test, y_train, y_test = model_selection.train_test_split(X, y, train_size=.8)
    clf.fit(X_train, y_train)
    print(dataset.length)
    return clf, X_test, y_test

# %%
dataset = scans_dataset(dataset="covid", library="torch")
random_sampler = RandomSampler(dataset, num_samples=300)

# %%
login()
# Out:
# Please paste your Comet API key from https://www.comet.com/api/my/settings/
# (api key may not show as you type)
# Comet API key:  ········
# COMET INFO: Valid Comet API Key saved in /root/.comet.config (set COMET_CONFIG to change where it is saved).

# %%
kernel_sizes = [2,3,4]
strides = [2, 3, 4]
epochs = [1000, 10000, 100000],
learning_rates = [.001, .01, .1]
batch_sizes = [3]
dropouts = [.1, .2, .25]
h_params = {'learning_rate': .01, 'epochs': 20, 'batch_size': 0, 'kernel_size': 0, 'stride': 1, 'dropout': 0}
for b in batch_sizes:
    for k in kernel_sizes:
        for d in dropouts:
            experiment = start(project="ml-project")
            h_params['batch_size'], h_params['kernel_size'], h_params['stride'], h_params['dropout'] = b, k, k, d                
            experiment.log_parameters(h_params)
            
            dataloader = DataLoader(subset, batch_size=b)
            
            image_model = scan_cnn(n_classes=4, input_channels=dataset.channels, image_size=(256,256), h_params=h_params).to(device)
            losses = train(dataloader, image_model, h_params, experiment)
            experiment.end()
# Out:
# COMET WARNING: As you are running in a Jupyter environment, you will need to call `experiment.end()` when finished to ensure all metrics and code are logged before exiting.
# COMET INFO: Experiment is live on comet.com https://www.comet.com/kelsbr123/ml-project/465ad6024ff244968093777a04366fc6
#
# COMET WARNING: Unknown error exporting current conda environment
# COMET WARNING: Unknown error retrieving Conda package as an explicit file
# COMET WARNING: Unknown error retrieving Conda information
# COMET INFO: ---------------------------------------------------------------------------------------
# COMET INFO: Comet.ml Experiment Summary
# COMET INFO: ---------------------------------------------------------------------------------------
# COMET INFO:   Data:
# COMET INFO:     display_summary_level : 1
# COMET INFO:     name                  : technological_relativity_217
# COMET INFO:     url                   : https://www.comet.com/kelsbr123/ml-project/465ad6024ff244968093777a04366fc6
# COMET INFO:   Metrics [count] (min, max):
# COMET INFO:     accuracy [140]  : (33.333333333333336, 66.66666666666667)
# COMET INFO:     curr_epoch [20] : (0, 19)
# COMET INFO:     loss [154]      : (0.7307312488555908, 158.70697021484375)
# COMET INFO:   Parameters:
# COMET INFO:     batch_size    : 3
# COMET INFO:     dropout       : 0.1
# COMET INFO:     epochs        : 20
# COMET INFO:     kernel_size   : 2
# COMET INFO:     learning_rate : 0.01
# COMET INFO:     stride        : 2
# COMET INFO:   Uploads:
# COMET INFO:     environment details      : 1
# COMET INFO:     filename                 : 1
# COMET INFO:     git metadata             : 1
# COMET INFO:     git-patch (uncompressed) : 1 (37.16 KB)
# COMET INFO:     installed packages       : 1
# COMET INFO:     model graph              : 1
# COMET INFO:     notebook                 : 1
# COMET INFO:     os packages              : 1
# COMET INFO:     source_code              : 1
# COMET INFO:
# COMET WARNING: As you are running in a Jupyter environment, you will need to call `experiment.end()` when finished to ensure all metrics and code are logged before exiting.
# COMET INFO: Experiment is live on comet.com https://www.comet.com/kelsbr123/ml-project/7062a5b10c904ec593882052d18c40a4
#
# COMET WARNING: Unknown error exporting current conda environment
# COMET WARNING: Unknown error retrieving Conda package as an explicit file
# COMET WARNING: Unknown error retrieving Conda information
# COMET INFO: ---------------------------------------------------------------------------------------
# COMET INFO: Comet.ml Experiment Summary
# COMET INFO: ---------------------------------------------------------------------------------------
# COMET INFO:   Data:
# COMET INFO:     display_summary_level : 1
# COMET INFO:     name                  : convincing_cobra_2077
# COMET INFO:     url                   : https://www.comet.com/kelsbr123/ml-project/7062a5b10c904ec593882052d18c40a4
# COMET INFO:   Metrics [count] (min, max):
# COMET INFO:     accuracy [140]  : (33.333333333333336, 50.0)
# COMET INFO:     curr_epoch [20] : (0, 19)
# COMET INFO:     loss [154]      : (1.175150990486145, 118.59406280517578)
# COMET INFO:   Parameters:
# COMET INFO:     batch_size    : 3
# COMET INFO:     dropout       : 0.2
# COMET INFO:     epochs        : 20
# COMET INFO:     kernel_size   : 2
# COMET INFO:     learning_rate : 0.01
# COMET INFO:     stride        : 2
# COMET INFO:   Uploads:
# COMET INFO:     environment details      : 1
# COMET INFO:     filename                 : 1
# COMET INFO:     git metadata             : 1
# COMET INFO:     git-patch (uncompressed) : 1 (37.16 KB)
# COMET INFO:     installed packages       : 1
# COMET INFO:     model graph              : 1
# COMET INFO:     notebook                 : 1
# COMET INFO:     os packages              : 1
# COMET INFO:     source_code              : 1
# COMET INFO:
# COMET WARNING: As you are running in a Jupyter environment, you will need to call `experiment.end()` when finished to ensure all metrics and code are logged before exiting.
# COMET INFO: Experiment is live on comet.com https://www.comet.com/kelsbr123/ml-project/2855b2d3139f48fcb48058aa4db45107
#
# COMET WARNING: Unknown error exporting current conda environment
# COMET WARNING: Unknown error retrieving Conda package as an explicit file
# COMET WARNING: Unknown error retrieving Conda information
# COMET INFO: ---------------------------------------------------------------------------------------
# COMET INFO: Comet.ml Experiment Summary
# COMET INFO: ---------------------------------------------------------------------------------------
# COMET INFO:   Data:
# COMET INFO:     display_summary_level : 1
# COMET INFO:     name                  : victorious_dolphin_6559
# COMET INFO:     url                   : https://www.comet.com/kelsbr123/ml-project/2855b2d3139f48fcb48058aa4db45107
# COMET INFO:   Metrics [count] (min, max):
# COMET INFO:     accuracy [140]  : (30.0, 35.0)
# COMET INFO:     curr_epoch [20] : (0, 19)
# COMET INFO:     loss [154]      : (0.6969254016876221, 99.95648956298828)
# COMET INFO:   Parameters:
# COMET INFO:     batch_size    : 3
# COMET INFO:     dropout       : 0.3
# COMET INFO:     epochs        : 20
# COMET INFO:     kernel_size   : 2
# COMET INFO:     learning_rate : 0.01
# COMET INFO:     stride        : 2
# COMET INFO:   Uploads:
# COMET INFO:     environment details      : 1
# COMET INFO:     filename                 : 1
# COMET INFO:     git metadata             : 1
# COMET INFO:     git-patch (uncompressed) : 1 (37.16 KB)
# COMET INFO:     installed packages       : 1
# COMET INFO:     model graph              : 1
# COMET INFO:     notebook                 : 1
# COMET INFO:     os packages              : 1
# COMET INFO:     source_code              : 1
# COMET INFO:
# COMET WARNING: As you are running in a Jupyter environment, you will need to call `experiment.end()` when finished to ensure all metrics and code are logged before exiting.
# COMET INFO: Experiment is live on comet.com https://www.comet.com/kelsbr123/ml-project/9fe4478e79744dfdb8fcddf69a3346d6
#
# COMET WARNING: Unknown error exporting current conda environment
# COMET WARNING: Unknown error retrieving Conda package as an explicit file
# COMET WARNING: Unknown error retrieving Conda information
# COMET INFO: ---------------------------------------------------------------------------------------
# COMET INFO: Comet.ml Experiment Summary
# COMET INFO: ---------------------------------------------------------------------------------------
# COMET INFO:   Data:
# COMET INFO:     display_summary_level : 1
# COMET INFO:     name                  : amaranth_plate_6376
# COMET INFO:     url                   : https://www.comet.com/kelsbr123/ml-project/9fe4478e79744dfdb8fcddf69a3346d6
# COMET INFO:   Metrics [count] (min, max):
# COMET INFO:     accuracy [140]  : (0.0, 66.66666666666667)
# COMET INFO:     curr_epoch [20] : (0, 19)
# COMET INFO:     loss [154]      : (0.693152129650116, 9.180580139160156)
# COMET INFO:   Parameters:
# COMET INFO:     batch_size    : 3
# COMET INFO:     dropout       : 0.1
# COMET INFO:     epochs        : 20
# COMET INFO:     kernel_size   : 3
# COMET INFO:     learning_rate : 0.01
# COMET INFO:     stride        : 3
# COMET INFO:   Uploads:
# COMET INFO:     environment details      : 1
# COMET INFO:     filename                 : 1
# COMET INFO:     git metadata             : 1
# COMET INFO:     git-patch (uncompressed) : 1 (37.16 KB)
# COMET INFO:     installed packages       : 1
# COMET INFO:     model graph              : 1
# COMET INFO:     notebook                 : 1
# COMET INFO:     os packages              : 1
# COMET INFO:     source_code              : 1
# COMET INFO:
# COMET WARNING: As you are running in a Jupyter environment, you will need to call `experiment.end()` when finished to ensure all metrics and code are logged before exiting.
# COMET INFO: Experiment is live on comet.com https://www.comet.com/kelsbr123/ml-project/d1ff6acad0cc46dc9568f4321e24a46c
#
# COMET WARNING: Unknown error exporting current conda environment
# COMET WARNING: Unknown error retrieving Conda package as an explicit file
# COMET WARNING: Unknown error retrieving Conda information
# COMET INFO: ---------------------------------------------------------------------------------------
# COMET INFO: Comet.ml Experiment Summary
# COMET INFO: ---------------------------------------------------------------------------------------
# COMET INFO:   Data:
# COMET INFO:     display_summary_level : 1
# COMET INFO:     name                  : flat_glacier_8188
# COMET INFO:     url                   : https://www.comet.com/kelsbr123/ml-project/d1ff6acad0cc46dc9568f4321e24a46c
# COMET INFO:   Metrics [count] (min, max):
# COMET INFO:     accuracy [140]  : (0.0, 66.66666666666667)
# COMET INFO:     curr_epoch [20] : (0, 19)
# COMET INFO:     loss [154]      : (0.6933587193489075, 9.188339233398438)
# COMET INFO:   Parameters:
# COMET INFO:     batch_size    : 3
# COMET INFO:     dropout       : 0.2
# COMET INFO:     epochs        : 20
# COMET INFO:     kernel_size   : 3
# COMET INFO:     learning_rate : 0.01
# COMET INFO:     stride        : 3
# COMET INFO:   Uploads:
# COMET INFO:     environment details      : 1
# COMET INFO:     filename                 : 1
# COMET INFO:     git metadata             : 1
# COMET INFO:     git-patch (uncompressed) : 1 (37.16 KB)
# COMET INFO:     installed packages       : 1
# COMET INFO:     model graph              : 1
# COMET INFO:     notebook                 : 1
# COMET INFO:     os packages              : 1
# COMET INFO:     source_code              : 1
# COMET INFO:
# COMET WARNING: As you are running in a Jupyter environment, you will need to call `experiment.end()` when finished to ensure all metrics and code are logged before exiting.
# COMET INFO: Experiment is live on comet.com https://www.comet.com/kelsbr123/ml-project/aa9a2616052f480983012eeea42fde56
#
# COMET WARNING: Unknown error exporting current conda environment
# COMET WARNING: Unknown error retrieving Conda package as an explicit file
# COMET WARNING: Unknown error retrieving Conda information
# COMET INFO: ---------------------------------------------------------------------------------------
# COMET INFO: Comet.ml Experiment Summary
# COMET INFO: ---------------------------------------------------------------------------------------
# COMET INFO:   Data:
# COMET INFO:     display_summary_level : 1
# COMET INFO:     name                  : collective_chili_2959
# COMET INFO:     url                   : https://www.comet.com/kelsbr123/ml-project/aa9a2616052f480983012eeea42fde56
# COMET INFO:   Metrics [count] (min, max):
# COMET INFO:     accuracy [140]  : (0.0, 66.66666666666667)
# COMET INFO:     curr_epoch [20] : (0, 19)
# COMET INFO:     loss [154]      : (0.6931570172309875, 6.379299163818359)
# COMET INFO:   Parameters:
# COMET INFO:     batch_size    : 3
# COMET INFO:     dropout       : 0.3
# COMET INFO:     epochs        : 20
# COMET INFO:     kernel_size   : 3
# COMET INFO:     learning_rate : 0.01
# COMET INFO:     stride        : 3
# COMET INFO:   Uploads:
# COMET INFO:     environment details      : 1
# COMET INFO:     filename                 : 1
# COMET INFO:     git metadata             : 1
# COMET INFO:     git-patch (uncompressed) : 1 (37.16 KB)
# COMET INFO:     installed packages       : 1
# COMET INFO:     model graph              : 1
# COMET INFO:     notebook                 : 1
# COMET INFO:     os packages              : 1
# COMET INFO:     source_code              : 1
# COMET INFO:
# COMET WARNING: As you are running in a Jupyter environment, you will need to call `experiment.end()` when finished to ensure all metrics and code are logged before exiting.
# COMET INFO: Experiment is live on comet.com https://www.comet.com/kelsbr123/ml-project/063aab8141e546879cf92db200ea21f9
#
# COMET WARNING: Unknown error exporting current conda environment
# COMET WARNING: Unknown error retrieving Conda package as an explicit file
# COMET WARNING: Unknown error retrieving Conda information
# COMET INFO: ---------------------------------------------------------------------------------------
# COMET INFO: Comet.ml Experiment Summary
# COMET INFO: ---------------------------------------------------------------------------------------
# COMET INFO:   Data:
# COMET INFO:     display_summary_level : 1
# COMET INFO:     name                  : valuable_range_9821
# COMET INFO:     url                   : https://www.comet.com/kelsbr123/ml-project/063aab8141e546879cf92db200ea21f9
# COMET INFO:   Metrics [count] (min, max):
# COMET INFO:     accuracy [140]  : (0.0, 66.66666666666667)
# COMET INFO:     curr_epoch [20] : (0, 19)
# COMET INFO:     loss [154]      : (0.6931540966033936, 6.469969272613525)
# COMET INFO:   Parameters:
# COMET INFO:     batch_size    : 3
# COMET INFO:     dropout       : 0.1
# COMET INFO:     epochs        : 20
# COMET INFO:     kernel_size   : 4
# COMET INFO:     learning_rate : 0.01
# COMET INFO:     stride        : 4
# COMET INFO:   Uploads:
# COMET INFO:     environment details      : 1
# COMET INFO:     filename                 : 1
# COMET INFO:     git metadata             : 1
# COMET INFO:     git-patch (uncompressed) : 1 (28.19 KB)
# COMET INFO:     installed packages       : 1
# COMET INFO:     model graph              : 1
# COMET INFO:     notebook                 : 1
# COMET INFO:     os packages              : 1
# COMET INFO:     source_code              : 1
# COMET INFO:
# COMET WARNING: As you are running in a Jupyter environment, you will need to call `experiment.end()` when finished to ensure all metrics and code are logged before exiting.
# COMET INFO: Experiment is live on comet.com https://www.comet.com/kelsbr123/ml-project/6dc5587fee0e451eb20bdbf9abb88fba
#
# COMET WARNING: Unknown error exporting current conda environment
# COMET WARNING: Unknown error retrieving Conda package as an explicit file
# COMET WARNING: Unknown error retrieving Conda information
# COMET INFO: ---------------------------------------------------------------------------------------
# COMET INFO: Comet.ml Experiment Summary
# COMET INFO: ---------------------------------------------------------------------------------------
# COMET INFO:   Data:
# COMET INFO:     display_summary_level : 1
# COMET INFO:     name                  : holy_bulb_3003
# COMET INFO:     url                   : https://www.comet.com/kelsbr123/ml-project/6dc5587fee0e451eb20bdbf9abb88fba
# COMET INFO:   Metrics [count] (min, max):
# COMET INFO:     accuracy [140]  : (0.0, 41.666666666666664)
# COMET INFO:     curr_epoch [20] : (0, 19)
# COMET INFO:     loss [154]      : (0.6931474208831787, 6.921200275421143)
# COMET INFO:   Parameters:
# COMET INFO:     batch_size    : 3
# COMET INFO:     dropout       : 0.2
# COMET INFO:     epochs        : 20
# COMET INFO:     kernel_size   : 4
# COMET INFO:     learning_rate : 0.01
# COMET INFO:     stride        : 4
# COMET INFO:   Uploads:
# COMET INFO:     environment details      : 1
# COMET INFO:     filename                 : 1
# COMET INFO:     git metadata             : 1
# COMET INFO:     git-patch (uncompressed) : 1 (28.19 KB)
# COMET INFO:     installed packages       : 1
# COMET INFO:     model graph              : 1
# COMET INFO:     notebook                 : 1
# COMET INFO:     os packages              : 1
# COMET INFO:     source_code              : 1
# COMET INFO:
# COMET WARNING: As you are running in a Jupyter environment, you will need to call `experiment.end()` when finished to ensure all metrics and code are logged before exiting.
# COMET INFO: Experiment is live on comet.com https://www.comet.com/kelsbr123/ml-project/1132037cc2d0406fb2feaceaf83f5e05
#
# COMET WARNING: Unknown error exporting current conda environment
# COMET WARNING: Unknown error retrieving Conda package as an explicit file
# COMET WARNING: Unknown error retrieving Conda information
# COMET INFO: ---------------------------------------------------------------------------------------
# COMET INFO: Comet.ml Experiment Summary
# COMET INFO: ---------------------------------------------------------------------------------------
# COMET INFO:   Data:
# COMET INFO:     display_summary_level : 1
# COMET INFO:     name                  : mathematical_brad_5004
# COMET INFO:     url                   : https://www.comet.com/kelsbr123/ml-project/1132037cc2d0406fb2feaceaf83f5e05
# COMET INFO:   Metrics [count] (min, max):
# COMET INFO:     accuracy [140]  : (0.0, 66.66666666666667)
# COMET INFO:     curr_epoch [20] : (0, 19)
# COMET INFO:     loss [154]      : (0.6931471824645996, 4.994587421417236)
# COMET INFO:   Parameters:
# COMET INFO:     batch_size    : 3
# COMET INFO:     dropout       : 0.3
# COMET INFO:     epochs        : 20
# COMET INFO:     kernel_size   : 4
# COMET INFO:     learning_rate : 0.01
# COMET INFO:     stride        : 4
# COMET INFO:   Uploads:
# COMET INFO:     environment details      : 1
# COMET INFO:     filename                 : 1
# COMET INFO:     git metadata             : 1
# COMET INFO:     git-patch (uncompressed) : 1 (28.19 KB)
# COMET INFO:     installed packages       : 1
# COMET INFO:     model graph              : 1
# COMET INFO:     notebook                 : 1
# COMET INFO:     os packages              : 1
# COMET INFO:     source_code              : 1
# COMET INFO:

# %%
clf, X_test, y_test = train_svm(dataset)
# Out:
# 21165

# %%
print(metrics.classification_report(y_test, clf.predict(X_test)))
# Out:
#               precision    recall  f1-score   support
#
#            1       0.75      0.24      0.36        25
#            2       0.72      0.72      0.72        32
#            3       0.69      0.93      0.79        58
#            4       1.00      0.50      0.67         6
#
#     accuracy                           0.71       121
#    macro avg       0.79      0.60      0.64       121
# weighted avg       0.73      0.71      0.68       121

# %%
avg_loss = []
for i in range(0,len(losses), 7):
    avg_loss.append(np.average(losses[i:i+7]))

plt.semilogy(list(range(0,len(avg_loss))), avg_loss)
plt.title("Average loss versus epoch")
plt.xlabel("Epoch")
plt.ylabel("Log Loss")
# Out:
# Text(0, 0.5, 'Log Loss')
